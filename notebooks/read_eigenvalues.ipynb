# %% [markdown]
# # Read the stored eigenvalues from our runs

# %%
import wandb

# 1. Initialize the API
api = wandb.Api()

# 2. Access the run
run = api.run("adaptive-muon/hessian-metrics/m43swhc0")

# 3. Read a specific item from the summary
len(run.summary["Group3_Conv2/eigenvalues"])
run.history
# Out:
# <bound method Run.history of <Run adaptive-muon/hessian-metrics/m43swhc0 (killed)>>
